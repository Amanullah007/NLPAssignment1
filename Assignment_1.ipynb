# %% [markdown]
# #### Team members: Syed Araib Karim, Amanullah Shareef, Soumya Bhandari, Guntupalli Naga Srija

# %%
from bs4 import BeautifulSoup
import urllib.request
import nltk
from nltk.corpus import stopwords
import nltk
from collections import Counter
nltk.download('stopwords')

def removeElements(lst, k):
    counted = Counter(lst)
      
    temp_lst = []
    for el in counted:
        if counted[el] < k:
            temp_lst.append(el)
              
    res_lst = []
    for el in lst:
        if el not in temp_lst:
            res_lst.append(el)
              
    return(res_lst)

response = urllib.request.urlopen('https://en.wikipedia.org/wiki/SpaceX')
html = response.read()
soup = BeautifulSoup(html,"html5lib")
text = soup.get_text(strip=True)
tokens = [t for t in text.split()]
clean_tokens = tokens[:]
sr = stopwords.words('english')
for token in tokens:
  if token in stopwords.words('english'):
    clean_tokens.remove(token)

# removing single characters and words containing numbers
clean_tokens = [i for i in clean_tokens if len(i) > 1 if not any(c.isdigit() for c in i)]

# removing elements which are mentioned 5 or less times.
clean_tokens = removeElements(clean_tokens,5)

freq = nltk.FreqDist(clean_tokens)
for key,val in freq.items():
  print (str(key) + ':' + str(val))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# SpaceX:144
# articles:6
# dead:10
# external:6
# August:34
# original:175
# American:7
# September:30
# using:7
# company:38
# containing:6
# October:19
# identifiers","Articles:8
# companies:13
# United:7
# established:6
# launch:96
# service:6
# based:8
# Los:11
# Angeles:8
# Greater:6
# technology:5
# private:22
# aerospace:5
# article:17
# rocket:39
# For:6
# Exploration:7
# Technologies:6
# December:45
# flight:18
# Falcon:92
# May:69
# landing:20
# billion:17
# Musk:31
# part:7
# series:5
# Boring:8
# Crew:24
# Test:9
# space:23
# costs:6
# crew:12
# spacecraft:18
# achievements:5
# first:80
# privately:6
# orbit:10
# successfully:14
# orbit,:6
# send:10
# International:7
# Space:72
# Station:6
# orbital:15
# reuse:5
# astronauts:9
# theInternational:14
# Dragon:45
# one:11
# developing:6
# satellite:27
# Starlink:25
# provide:13
# commercial:22
# internet:7
# In:12
# January:34
# constellation:9
# largest:5
# also:15
# Starship:25
# become:5
# vehicle:15
# Heavy:15
# reusable:9
# payload:5
# early:14
# Dragon,:6
# NASA:34
# Commercial:10
# launches:21
# global:7
# crewed:12
# spaceport:10
# drone:9
# test:27
# Canaveral:6
# Force:22
# manufacturing:6
# market:7
# competition:5
# announced:13
# would:12
# rockets:10
# could:6
# started:5
# new:18
# SpaceX.:17
# SpaceX's:19
# business:6
# Musk,:5
# November:31
# cost:9
# developed:7
# The:37
# total:8
# development:20
# approximately:13
# plans:8
# program:6
# theDragon:6
# two:10
# cargo:19
# resupply:5
# contracts:14
# ISS:10
# States:9
# vehicles:6
# use:8
# three:11
# nearly:7
# time:6
# around:5
# successful:9
# achieved:5
# million:22
# awarded:12
# Services:5
# following:8
# July:33
# time,:5
# CRS:6
# contract:19
# operational:5
# Development:6
# several:5
# flights:8
# This:5
# Orbital:5
# funding:6
# launched:27
# June:41
# Demo:5
# Flight:10
# second:8
# mission:12
# April:40
# develop:8
# transport:8
# missions:13
# system:6
# estimated:5
# worth:6
# equity:8
# valuation:8
# operated:6
# began:7
# late:6
# testing:6
# February:56
# U.S.:18
# large:7
# Launch:21
# raised:6
# stage:11
# fly:5
# reused:6
# used:13
# March:63
# number:6
# SpaceX,:7
# Elon:16
# Texas:7
# Complex:5
# It:5
# As:5
# Musk's:17
# booster:7
# security:6
# article:SpaceX:5
# Block:5
# Earth:10
# Rocket:7
# engines:5
# engine:11
# four:5
# XL:6
# station:8
# Gateway:5
# site:6
# Mars:6
# missions,:5
# satellites:11
# additional:8
# since:12
# operates:6
# another:5
# Air:16
# facility:11
# national:6
# ULA:5
# .citation:6
# a,.mw-parser-output:5
# Business:5
# Archived:26
# fromthe:25
# originalon:20
# theWayback:5
# Eric:9
# Morrow:6
# Company.:6
# p.:7
# Spaceflight:11
# News.Archivedfrom:6
# incorporates:15
# text:15
# source,:15
# thepublic:15
# original(PDF)on:5
# B.:5
# de:6
# Selding:5
# SpaceNews.Archivedfrom:7
# SpaceNews.:8
# Times.Archivedfrom:8
# New:10
# York:7
# Michael:5
# wins:5
# Now.Archivedfrom:5
# NASA.Archivedfrom:5
# identifiersArticles:8

# %%
freq.plot(10, cumulative= False)

# %%
import matplotlib.pyplot as plt
import numpy

#converting values into absolute values for plotting
def absolute_value(val):
    a  = numpy.round(val/100.*all_fdist.sum(), 0)
    return a
plt.pie(all_fdist.values,labels=all_fdist.index,autopct=absolute_value)
plt.title('Top 10 common words')
plt.axis('equal')
plt.show()
